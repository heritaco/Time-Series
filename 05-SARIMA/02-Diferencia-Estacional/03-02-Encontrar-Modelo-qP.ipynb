# %% [markdown]
# <style>
# body {
#     max-width: 900px;
#     margin: 40px auto;
#     padding: 0 20px;
#     font-family: "Georgia", serif;
#     line-height: 1.6;
# }
# </style>
#
# <div style="text-align: center; padding: 60px 60px">
#   <h1 style="font-weight: bold; font-size: 3.1em">
#     ENCONTRAR EL MEJOR ARIMA PARA LA SERIE DIFERENCIADA
#   </h1>
# </div>

# %% [markdown]
# Se busca mejorar el **modelo 14**, encontrado en `03-Encontrar-Modelos-que-Cumplan`, variando la parte estacional autoregresiva y la parte media móvil.
#
# Es decir, en esta notebook se fijan los valores de $\text{ARIMA}(0, 0, q) \times (P, 1, 0, 12)$ donde $P = 0, 1, 2, \dots$ y $q = 0, 1, 2, \dots$. Esto por la *Observación (2)* de `03-----Encontrar-Modelos-que-Cumplan`.

# %% [markdown]
# **RESULTADOS**: Intentando mejorar el modelo, obtuvimos el mismo resultado que en el archivo `03-01`.
# - El modelo con menor $\text{AIC}$ es el $\text{ARIMA}(0,0,15) \times (0,1,0)$,  Con un $\text{AIC} = 1370.8057965209173$.
# - `aic_values-2.csv`
# - `AIC_3D_plot_2.html`.

# %% [markdown]
# # **CARGAR LOS DATOS**

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd

data=pd.read_csv('MXN00021035.csv')

pre=data.iloc[:,6]  # Precipitacion, es la columna 5
date=data.iloc[:,5] # Date, es la columna 6
date = date.astype(str).str.replace(r'(\d{4})(\d{2})', r'\1/\2', regex=True)    # La fecha está como 195210 y la pasamos a 1952/10 
date = pd.to_datetime(date, format='%Y/%m')                                     # Lo convertimos en fecha
pre = pd.Series(pre.values, index=date)                                         # Creamos una Serie

# Partir la serie para train y test
pre_total = pre.copy()          # Copia de la serie original

# Todas hasta los ultimos 12 meses
pre = pre_total[:-12]           # Entrenamiento: todos menos los últimos 12 meses

from scipy.stats import zscore

# Estandarizar la serie original
zpre = zscore(pre)

# %% [markdown]
# # **BUSCAMOS EL MODELO CON MENOR $\text{AIC} $**

# %% [markdown]
# Se fue probando varias veces, y se buscaba ir encontrando el mejor $\text{AIC}$  en saltos, porque hacer todos los modelos tarda mucho tiempo. Por eso tiene mucho menos granulidad esta vez, que en la vez pasada.

# %%
def sarima(p, d, q, P, D, Q, s):    # La vamos a usar para calcular el AIC
    return SARIMAX(zpre, order=(p, d, q), seasonal_order=(P, D, Q, s)).fit(disp=0).aic

# %% [markdown]
# Empezamos con el propuesto en 03

# %%
aics = []   # Lista para guardar los AICs

# %%
q = 12
P = 4

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
q = 12
P = 2

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
q = 10
P = 2

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
q = 14
P = 2

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
q = 10
P = 3

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
q = 11
P = 3

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
q = 11
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
q = 11
P = 2

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
q = 12
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
q = 12
P = 0

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
q = 15
P = 0

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
q = 15
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
q = 6
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
q = 8
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
q = 10
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
q = 13
P = 1

p = 0
d = 0
D = 1
Q = 0
s = 12

aics.append((p, d, q, P, D, Q, s, sarima(p, d, q, P, D, Q, s)))
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
aics
# Out:
# [(0, 0, 12, 4, 1, 0, 12, 1375.925423758716),
#  (0, 0, 12, 2, 1, 0, 12, 1373.3656336045701),
#  (0, 0, 10, 2, 1, 0, 12, 1446.9730982835517),
#  (0, 0, 10, 3, 1, 0, 12, 1430.5116550954838),
#  (0, 0, 14, 2, 1, 0, 12, 1377.4904592990874),
#  (0, 0, 11, 3, 1, 0, 12, 1427.3484136655213),
#  (0, 0, 11, 1, 1, 0, 12, 1511.206969623386),
#  (0, 0, 11, 2, 1, 0, 12, 1443.1161753886217),
#  (0, 0, 12, 1, 1, 0, 12, 1372.790187286502),
#  (0, 0, 12, 0, 1, 0, 12, 1370.924382974263),
#  (0, 0, 15, 0, 1, 0, 12, 1370.8057965209173),
#  (0, 0, 15, 1, 1, 0, 12, 1373.1675718134138),
#  (0, 0, 6, 1, 1, 0, 12, 1514.47341581714),
#  (0, 0, 8, 1, 1, 0, 12, 1516.1508858594366),
#  (0, 0, 10, 1, 1, 0, 12, 1516.9787272802691),
#  (0, 0, 13, 1, 1, 0, 12, 1373.857130374262)]

# %%
sorted(aics, key=lambda x: x[7])
# Out:
# [(0, 0, 15, 0, 1, 0, 12, 1370.8057965209173),
#  (0, 0, 12, 0, 1, 0, 12, 1370.924382974263),
#  (0, 0, 12, 1, 1, 0, 12, 1372.790187286502),
#  (0, 0, 15, 1, 1, 0, 12, 1373.1675718134138),
#  (0, 0, 12, 2, 1, 0, 12, 1373.3656336045701),
#  (0, 0, 13, 1, 1, 0, 12, 1373.857130374262),
#  (0, 0, 12, 4, 1, 0, 12, 1375.925423758716),
#  (0, 0, 14, 2, 1, 0, 12, 1377.4904592990874),
#  (0, 0, 11, 3, 1, 0, 12, 1427.3484136655213),
#  (0, 0, 10, 3, 1, 0, 12, 1430.5116550954838),
#  (0, 0, 11, 2, 1, 0, 12, 1443.1161753886217),
#  (0, 0, 10, 2, 1, 0, 12, 1446.9730982835517),
#  (0, 0, 11, 1, 1, 0, 12, 1511.206969623386),
#  (0, 0, 6, 1, 1, 0, 12, 1514.47341581714),
#  (0, 0, 8, 1, 1, 0, 12, 1516.1508858594366),
#  (0, 0, 10, 1, 1, 0, 12, 1516.9787272802691)]

# %%
datos = sorted(aics, key=lambda x: x[7])

# Procesamos cada tupla
i = 1
for _, _, q, P, _, _, _, aic in datos:
    if i < 10:
        if P >= 10 and q < 10:
            print(f"({i})   ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        elif P >= 10 and q >= 10:
            print(f"({i})   ARIMA(0,0,{q})({P},1,0)[12]   AIC={aic:.2f}  ")
        elif P < 10 and q >= 10:
            print(f"({i})   ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        else:
            print(f"({i})   ARIMA(0,0,{q})({P},1,0)[12]     AIC={aic:.2f}  ")
    if i >= 10 and i < 100:
        if P >= 10 and q < 10:
            print(f"({i})  ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        elif P >= 10 and q >= 10:
            print(f"({i})  ARIMA(0,0,{q})({P},1,0)[12]   AIC={aic:.2f}  ")
        elif P < 10 and q >= 10:
            print(f"({i})  ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        else:
            print(f"({i})  ARIMA(0,0,{q})({P},1,0)[12]     AIC={aic:.2f}  ")
    elif i >= 100:
        if P >= 10 and q < 10:
            print(f"({i}) ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        elif P >= 10 and q >= 10:
            print(f"({i}) ARIMA(0,0,{q})({P},1,0)[12]   AIC={aic:.2f}  ")
        elif P < 10 and q >= 10:
            print(f"({i}) ARIMA(0,0,{q})({P},1,0)[12]    AIC={aic:.2f}  ")
        else:
            print(f"({i}) ARIMA(0,0,{q})({P},1,0)[12]     AIC={aic:.2f}  ")
    i += 1

# %% [markdown]
# Nos dió lo mismo que en el archivo 04. El modelo con menor $\text{AIC}$ es el $\text{ARIMA}(0,0,15) \times (0,1,0)$,  Con un $\text{AIC} = 1370.8057965209173$.

# %%
# Guardar los valores AIC en un archivo CSV
aic_df = pd.DataFrame(aics, columns=['p', 'd', 'q', 'P', 'D', 'Q', 's', 'AIC'])
aic_df.to_csv('aic_values-2.csv', index=False)

# %% [markdown]
# # **VISUALIZACIÓN**

# %%
import plotly.graph_objects as go
import numpy as np
from scipy.interpolate import griddata
import pandas as pd

# %%
aics = pd.read_csv('aic_values-2.csv')

# %%
# Separar en listas
p_values = aics['P'].tolist()
q_values = aics['q'].tolist()
aic_values = aics['AIC'].tolist()

# Crear una malla regular
p_lin = np.linspace(min(p_values), max(p_values), 50)
q_lin = np.linspace(min(q_values), max(q_values), 50)
P, Q = np.meshgrid(p_lin, q_lin)

# Interpolar AIC en la malla
AIC_grid = griddata(
    points=(p_values, q_values),
    values=aic_values,
    xi=(P, Q),
    method='nearest'
)

# %%
# Crear figura 3D en Plotly
fig = go.Figure()

# Superficie
fig.add_trace(go.Surface(
    x=P, y=Q, z=AIC_grid,
    colorscale='Blues_r',
    opacity=0.7,
    colorbar=dict(title='AIC')
))

# Puntos originales
fig.add_trace(go.Scatter3d(
    x=p_values,
    y=q_values,
    z=aic_values,
    mode='markers',
    marker=dict(size=5, color=aic_values, colorscale='Blues_r'),
    name='Puntos'
))

# Layout
fig.update_layout(
    scene=dict(
        xaxis_title='P',
        yaxis_title='q',
        zaxis_title='AIC'
    ),
    title='AIC para diferentes combinaciones de ARIMA(0,0,q)X(P,1,0,12)',
    width=900,
    height=700
)

# Guardar como HTML
fig.write_html("AIC_3D_plot-2.html")
fig.show()

# %% [markdown]
# # **VERIFICACIÓN DE SUPUESTOS**

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from verificacion_de_supuestos import * # Una funcion que hice para verificar si los parametros son estacionarios/invertibles
from statsmodels.stats.diagnostic import acorr_ljungbox
from scipy.stats import ttest_1samp
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.tools.tools import add_constant
from scipy.stats import jarque_bera
from statsmodels.stats.diagnostic import lilliefors

# %%
modelo=SARIMAX(zpre,
               order=(0,0,15),
               seasonal_order=(0,1,0,12)).fit()

modelo.summary()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  660
# Model:             SARIMAX(0, 0, 15)x(0, 1, [], 12)   Log Likelihood                -669.403
# Date:                              Sat, 26 Apr 2025   AIC                           1370.806
# Time:                                      21:50:48   BIC                           1442.388
# Sample:                                           0   HQIC                          1398.575
#                                               - 660
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1367      0.037      3.666      0.000       0.064       0.210
# ma.L2          0.0006      0.041      0.014      0.988      -0.080       0.081
# ma.L3          0.0767      0.041      1.866      0.062      -0.004       0.157
# ma.L4         -0.0764      0.040     -1.892      0.058      -0.155       0.003
# ma.L5         -0.1454      0.038     -3.816      0.000      -0.220      -0.071
# ma.L6         -0.1591      0.041     -3.922      0.000      -0.239      -0.080
# ma.L7         -0.0977      0.038     -2.566      0.010      -0.172      -0.023
# ma.L8         -0.0202      0.036     -0.554      0.580      -0.091       0.051
# ma.L9          0.0189      0.035      0.543      0.587      -0.049       0.087
# ma.L10         0.0721      0.034      2.104      0.035       0.005       0.139
# ma.L11         0.1653      0.035      4.718      0.000       0.097       0.234
# ma.L12        -0.7787      0.036    -21.409      0.000      -0.850      -0.707
# ma.L13        -0.0483      0.041     -1.178      0.239      -0.129       0.032
# ma.L14        -0.0184      0.039     -0.469      0.639      -0.095       0.059
# ma.L15        -0.1024      0.043     -2.372      0.018      -0.187      -0.018
# sigma2         0.4461      0.021     21.164      0.000       0.405       0.487
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               360.03
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.80   Skew:                             0.86
# Prob(H) (two-sided):                  0.10   Kurtosis:                         6.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
estacionario(modelo)
# Out:
# El polinomio de la parte autoregresiva es: {}
#
# El grado del polinomio es: 0
#
# Raíces del polinomio característico: []
#
# Módulo de las raíces: []
#
# ¿Las raíces están fuera del círculo unitario?  True
#
# El modelo es estacionario
#
# :)

# %%
invertible(modelo)
# Out:
# El polinomio de la parte media móvil es: {'p1': 0.13670240371999162, 'p2': 0.0005971888480305956, 'p3': 0.07670095541918637, 'p4': -0.07637154759112381, 'p5': -0.14537162831990777, 'p6': -0.1591494261114962, 'p7': -0.09765166095390075, 'p8': -0.020150469201547817, 'p9': 0.018894086400221687, 'p10': 0.07211092136133603, 'p11': 0.1652919906997901, 'p12': -0.7787367794635099, 'p13': -0.04830339922205925, 'p14': -0.018407433802944403, 'p15': -0.10242070791381097}
#
# El grado del polinomio es: 15
#
# Raíces del polinomio característico: [ 0.8140251 +1.79974151j  0.8140251 -1.79974151j -2.00260148+0.j
#   0.95007946+0.50126699j  0.95007946-0.50126699j  1.00203779+0.j
#   0.51057431+0.86905551j  0.51057431-0.86905551j  0.00842192+1.0215353j
#   0.00842192-1.0215353j  -0.50272798+0.87137081j -0.50272798-0.87137081j
#  -1.00175188+0.j         -0.8690769 +0.50012473j -0.8690769 -0.50012473j]
#
# Módulo de las raíces: [1.97527375 1.97527375 2.00260148 1.07420649 1.07420649 1.00203779
#  1.00794028 1.00794028 1.02157001 1.02157001 1.0059933  1.0059933
#  1.00175188 1.00270604 1.00270604]
#
# ¿Las raíces están fuera del círculo unitario?  True
#
# El modelo es invertible
#
# :)

# %%
acorr_ljungbox(modelo.resid, period=24, model_df=len(modelo.params)-1)
# Out:
#       lb_stat  lb_pvalue
# 1    0.269005        NaN
# 2    0.273263        NaN
# 3    0.399129        NaN
# 4    0.417800        NaN
# 5    1.551264        NaN
# 6    1.980990        NaN
# 7    2.978212        NaN
# 8    3.536694        NaN
# 9    4.544775        NaN
# 10   4.576955        NaN
# 11   4.705108        NaN
# 12   4.861644        NaN
# 13   6.235540        NaN
# 14   6.293867        NaN
# 15   6.431435        NaN
# 16   6.507913   0.010740
# 17   8.144453   0.017039
# 18   8.163059   0.042759
# 19   8.202706   0.084429
# 20   8.284038   0.141261
# 21   8.293603   0.217373
# 22   8.502851   0.290345
# 23   8.521037   0.384295
# 24   8.780859   0.457744
# 25   8.837371   0.547604
# 26   8.903090   0.630837
# 27   9.302323   0.676914
# 28  10.220589   0.675804
# 29  10.252902   0.743470
# 30  10.253140   0.803522
# 31  10.253177   0.853077
# 32  12.490066   0.769597
# 33  12.863381   0.799624
# 34  14.070887   0.779543
# 35  14.071750   0.826839
# 36  14.331944   0.854923
# 37  14.430218   0.885509
# 38  14.450634   0.913237
# 39  14.526513   0.933852
# 40  14.560032   0.951070
# 41  14.954056   0.958169
# 42  15.101448   0.967985
# 43  15.154594   0.976758
# 44  15.362785   0.981977
# 45  15.399058   0.987281
# 46  15.419725   0.991210
# 47  15.433976   0.994025
# 48  16.098865   0.994106

# %% [markdown]
# Todos los residuos son independientes.

# %%
modelo.resid.mean()
# Out:
# -0.045524455453858546

# %% [markdown]
# Los residuos son un poco mejores que el modelo 14.

# %%
ttest_1samp(modelo.resid, 0)
# Out:
# TtestResult(statistic=-1.7052893997409186, pvalue=0.08861172351622751, df=659)

# %% [markdown]
# La media de los residuos es cero.

# %%
het_breuschpagan(modelo.resid, add_constant(np.arange(len(modelo.resid))))
# Out:
# (2.246413161692278, 0.1339245098780731, 2.247254731819336, 0.13433127866106115)

# %% [markdown]
# Puede ser una normal.
